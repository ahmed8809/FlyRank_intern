# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed8809/FlyRank_intern/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Lane 3: Structured Content Archetype Clustering
# I chose this lane because I think if we cluster the pages correctly we can apply
# our modification on a punch of pages that behave like each other also, This can
# help us to discover more correlation between those pages and users behaviour

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# this lane will improve understanding of the pages which will help to treat archetypes
# indpendently make the needed modifications for every punch of pages this will save
# More time from my prespective beacuse instead of work on a single page you will work
# on an archetype one time
# who acts on it ? simply it's pages
# worng call cost ? I think it will be a large cost because we won't work on individual
# page but a punch of them so wrong call once --> cost on whole archetype

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")  # move from notebooks/ to the repo root

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %%
# !{sys.executable} scripts/run_all.py
# Out:
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrank-ml-internship-starter/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/flyrank-ml-internship-starter/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...
# ▶ Step 3/5 — Train — logistic regression, decision tree, random forest (client-holdout split)
# ...
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/flyrank-ml-internship-starter/data/processed/model_predictions.csv
# Wrote model results: /content/flyrank-ml-internship-starter/outputs/model_results.json
#
# ...
# ▶ Step 4/5 — Evaluate — ranked refresh queue, charts, and the Markdown report
# ...

# %%
import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape[0], "rows,", df.shape[1], "columns")
# Out:
# 30000 rows, 44 columns

# %%
df.describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %%
# I am really can't pick 2-3 specific numbers but from the description of the data I think there is a null
# data or missing values also wome columns have an outliers but all of these things will be more clarified
# at the next weeks I think, Also I can't pick 2-3 numbers will help in the clustering process becuase until
# this moment I didn't understand data 100% to be honest.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# It's not about train model only because as I said above this will give us a
# better understanding for the pages of self , we will able to know the hidden
# connections between the pages which have the same archetype which will make us
# able to take the right desicions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
